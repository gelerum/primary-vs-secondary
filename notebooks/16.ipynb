# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/interim/04_train.parquet", engine="pyarrow")

# %%
df.head()
# Out:
#    longitude   latitude       area  room_count  floor market_type  build_year  \
# 0  37.525818  55.795322  52.490002           2      7     primary        2018
# 1  37.758976  55.808762  56.400002           2     13     primary        2018
# 2  37.758976  55.808762  56.599998           2     14     primary        2018
# 3  37.758976  55.808762  18.100000           1     14     primary        2018
# 4  37.758976  55.808762  37.700001           1     20     primary        2018
#
#    balcony       price  price_per_square_meter       date  year  month  day  \
# 0    False  17315138.0                329875.0 2018-01-01  2018      1    1
# 1    False   7696287.5                136459.0 2018-01-02  2018      1    2
# 2    False   7723579.5                136459.0 2018-01-02  2018      1    2
# 3    False   3461353.5                191235.0 2018-01-02  2018      1    2
# 4    False   5478941.0                145330.0 2018-01-02  2018      1    2
#
#   administrative_district
# 0                Северный
# 1               Восточный
# 2               Восточный
# 3               Восточный
# 4               Восточный

# %%
df1 = pd.read_parquet("../data/interim/04_train.parquet", engine="pyarrow")
