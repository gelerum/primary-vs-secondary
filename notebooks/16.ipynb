# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/interim/wnir_train.parquet", engine="pyarrow")

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'area', 'room_count', 'floor', 'build_year',
#        'balcony', 'date', 'year', 'month', 'day', 'administrative_district',
#        'price_per_square_meter_normalized', 'price_normalized', 'wnir_p_100',
#        'wnir_s_mean_100', 'wnir_s_std_100', 'wnir_s_min_100', 'wnir_s_max_100',
#        'wnir_s_median_100', 'wnir_s_count_100', 'wnir_p_500',
#        'wnir_s_mean_500', 'wnir_s_std_500', 'wnir_s_min_500', 'wnir_s_max_500',
#        'wnir_s_median_500', 'wnir_s_count_500', 'wnir_p_1000',
#        'wnir_s_mean_1000', 'wnir_s_std_1000', 'wnir_s_min_1000',
#        'wnir_s_max_1000', 'wnir_s_median_1000', 'wnir_s_count_1000',
#        'wnir_p_5000', 'wnir_s_mean_5000', 'wnir_s_std_5000', 'wnir_s_min_5000',
#        'wnir_s_max_5000', 'wnir_s_median_5000', 'wnir_s_count_5000',
#        'wnir_p_10000', 'wnir_s_mean_10000', 'wnir_s_std_10000',
#        'wnir_s_min_10000', 'wnir_s_max_10000', 'wnir_s_median_10000',
#        'wnir_s_count_10000'],
# ...

# %%
df.head()
# Out:
#    longitude   latitude       area  room_count  floor  build_year  balcony  \
# 0  37.257538  55.873539  34.400002           1      7        2018    False
# 1  37.400261  55.869251  56.700001           2      7        2018    False
# 2  37.910217  55.699482  38.689999           1     10        2018    False
# 3  37.645638  55.537201  30.600000           1      7        2018    False
# 4  37.703106  55.561600  35.099998           1     12        2018    False
#
#         date  year  month  ...  median_s_5000 count_s_5000  wnir_p_10000  \
# 0 2018-01-09  2018      1  ...            NaN          0.0           NaN
# 1 2018-01-09  2018      1  ...            NaN          0.0           NaN
# 2 2018-01-09  2018      1  ...            NaN          0.0           NaN
# 3 2018-01-10  2018      1  ...            NaN          0.0           NaN
# 4 2018-01-10  2018      1  ...            NaN          0.0           NaN
#
#    count_p_10000  mean_s_10000  std_s_10000  min_s_10000  max_s_10000  \
# ...

# %%
df1 = pd.read_parquet("../data/interim/04_train.parquet", engine="pyarrow")
