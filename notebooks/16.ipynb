# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/interim/umap_train.parquet", engine="pyarrow")

# %%
df.columns
# Out:
# Index(['date', 'year', 'month', 'day', 'price_per_square_meter_normalized',
#        'price_normalized', 'market_type', 'umap_1', 'umap_2', 'umap_3',
#        'umap_4', 'umap_5', 'umap_6', 'umap_7', 'umap_8', 'umap_9', 'umap_10'],
#       dtype='str')

# %%
df.head()
# Out:
#         date  year  month  day  price_per_square_meter_normalized  \
# 0 2018-01-01  2018      1    1                       839956.37500
# 1 2018-01-02  2018      1    2                       347463.75000
# 2 2018-01-02  2018      1    2                       347463.75000
# 3 2018-01-02  2018      1    2                       486939.15625
# 4 2018-01-02  2018      1    2                       370051.87500
#
#    price_normalized market_type    umap_1    umap_2    umap_3    umap_4  \
# 0        44089312.0     primary  2.999602 -2.620929 -1.330358 -1.565016
# 1        19596956.0     primary  0.113506 -4.589959 -3.187824  0.618227
# 2        19666448.0     primary  0.128101 -4.617190 -3.159699  0.630405
# 3         8813599.0     primary -1.482676  2.204778 -6.531068 -4.225670
# 4        13950956.0     primary -1.334885  1.947878 -6.175042 -3.712547
#
#      umap_5    umap_6    umap_7    umap_8    umap_9   umap_10
# 0 -1.759978  1.738214  1.021190  4.344946  2.077929  3.293862
# ...

# %%
df1 = pd.read_parquet("../data/interim/04_train.parquet", engine="pyarrow")
