# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/interim/price_discount_train.parquet", engine="pyarrow")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1211950 entries, 0 to 1211949
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   longitude                          1211950 non-null  float32
#  1   latitude                           1211950 non-null  float32
#  2   area                               1211950 non-null  float32
#  3   room_count                         1211950 non-null  UInt8
#  4   floor                              1211950 non-null  Int16
#  5   market_type                        1211950 non-null  category
#  6   build_year                         1211950 non-null  UInt16
#  7   balcony                            1211950 non-null  bool
#  8   date                               1211950 non-null  datetime64[ns]
#  9   year                               1211950 non-null  uint16
#  10  month                              1211950 non-null  uint8
# ...

# %%
df = pd.read_parquet("../data/interim/clean.parquet", engine="pyarrow")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1591301 entries, 0 to 1591300
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   address                 1591301 non-null  string
#  1   longitude               1550367 non-null  float32
#  2   latitude                1550367 non-null  float32
#  3   area                    1591301 non-null  float32
#  4   room_count              1591301 non-null  UInt8
#  5   floor                   1591301 non-null  Int16
#  6   market_type             1591301 non-null  category
#  7   build_year              1591301 non-null  UInt16
#  8   balcony                 1591301 non-null  bool
#  9   price                   1591301 non-null  float32
#  10  price_per_square_meter  1591301 non-null  float32
#  11  date                    1591301 non-null  datetime64[ns]
#  12  year                    1591301 non-null  uint16
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'area', 'room_count', 'floor', 'market_type',
#        'build_year', 'balcony', 'date', 'year', 'month', 'day',
#        'administrative_district', 'price_per_square_meter_normalized',
#        'price_normalized'],
#       dtype='str')

# %%
df.head()
# Out:
#         date  year  month  day  price_per_square_meter_normalized  \
# 0 2018-01-01  2018      1    1                       839956.37500
# 1 2018-01-02  2018      1    2                       347463.75000
# 2 2018-01-02  2018      1    2                       347463.75000
# 3 2018-01-02  2018      1    2                       486939.15625
# 4 2018-01-02  2018      1    2                       370051.87500
#
#    price_normalized market_type    umap_1    umap_2    umap_3    umap_4  \
# 0        44089312.0     primary  2.999602 -2.620929 -1.330358 -1.565016
# 1        19596956.0     primary  0.113506 -4.589959 -3.187824  0.618227
# 2        19666448.0     primary  0.128101 -4.617190 -3.159699  0.630405
# 3         8813599.0     primary -1.482676  2.204778 -6.531068 -4.225670
# 4        13950956.0     primary -1.334885  1.947878 -6.175042 -3.712547
#
#      umap_5    umap_6    umap_7    umap_8    umap_9   umap_10
# 0 -1.759978  1.738214  1.021190  4.344946  2.077929  3.293862
# ...

# %%
df1 = pd.read_parquet("../data/interim/04_train.parquet", engine="pyarrow")
