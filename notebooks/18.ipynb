# %%
import pandas as pd

# %%
df_wnir_traindf_wnir_train = pd.read_parquet(
    "../data/interim/clean.parquet", engine="pyarrow")

# %%
df_wnir_traindf_wnir_train['balcony'].value_counts()
# Out:
# balcony
# 0    1296835
# 1     305907
# Name: count, dtype: Int64
