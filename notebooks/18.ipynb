# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/interim/wnir_test.parquet", engine="pyarrow")

# %%
df["balcony"].value_counts()
# Out:
# balcony
# 0    55221
# Name: count, dtype: Int64

# %%
df.head(30)
# Out:
#     longitude   latitude       area  room_count  floor  build_year  balcony  \
# 0   37.785152  55.909767  34.200001           1     12        2025        0
# 1   37.758305  55.910294  32.400002           1     23        2025        0
# 2   37.786156  55.910454  40.200001           1      9        2025        0
# 3   37.291565  55.568455  64.800003           2      8        2025        0
# 4   37.786156  55.910454  32.299999           1     23        2025        0
# 5   37.759380  55.910061  35.799999           1     11        2025        0
# 6   37.169605  55.965363  53.700001           2     15        2025        0
# 7   37.432072  55.814106  75.500000           3      4        2025        0
# 8   37.420528  55.617420  33.500000           1      4        2025        0
# 9   37.637226  55.673645  32.500000           1     28        2025        0
# 10  37.169605  55.965363  32.400002           1     23        2025        0
# ...
